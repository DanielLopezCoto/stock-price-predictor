# %%
import yfinance as yf

# %%
dat = yf.Ticker("^GSPC")
dat.info
# Out:
# {'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 6038.81,
#  'open': 6049.38,
#  'dayLow': 6031.81,
#  'dayHigh': 6059.02,
#  'regularMarketPreviousClose': 6038.81,
#  'regularMarketOpen': 6049.38,
#  'regularMarketDayLow': 6031.81,
#  'regularMarketDayHigh': 6059.02,
#  'volume': 1018119000,
#  'regularMarketVolume': 1018119000,
#  'averageVolume': 5217935238,
#  'averageVolume10days': 4921211000,
#  'averageDailyVolume10Day': 4921211000,
#  'bid': 6046.68,
#  'ask': 6049.53,
#  'bidSize': 0,
#  'askSize': 0,
#  'fiftyTwoWeekLow': 4835.04,
#  'fiftyTwoWeekHigh': 6147.43,
#  'fiftyDayAverage': 5645.2407,
#  'twoHundredDayAverage': 5800.478,
#  'currency': 'USD',
#  'tradeable': False,
#  '52WeekChange': 11.39599,
#  'quoteType': 'INDEX',
#  'symbol': '^GSPC',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Index',
#  'quoteSourceName': 'Free Realtime Quote',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
# ...

# %%
dat.history(period='1mo')
# yf.download(["MSFT"])
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2025-05-12 00:00:00-04:00  5807.200195  5845.370117  5786.080078  5844.189941
# 2025-05-13 00:00:00-04:00  5854.149902  5906.640137  5845.020020  5886.549805
# 2025-05-14 00:00:00-04:00  5896.740234  5906.549805  5872.109863  5892.580078
# 2025-05-15 00:00:00-04:00  5869.819824  5924.209961  5865.160156  5916.930176
# 2025-05-16 00:00:00-04:00  5929.089844  5958.620117  5907.359863  5958.379883
# 2025-05-19 00:00:00-04:00  5902.879883  5968.609863  5895.689941  5963.600098
# 2025-05-20 00:00:00-04:00  5944.660156  5953.060059  5909.259766  5940.459961
# 2025-05-21 00:00:00-04:00  5910.180176  5938.370117  5830.910156  5844.609863
# 2025-05-22 00:00:00-04:00  5841.259766  5878.080078  5825.819824  5842.009766
# 2025-05-23 00:00:00-04:00  5781.890137  5829.509766  5767.410156  5802.819824
# 2025-05-27 00:00:00-04:00  5854.069824  5924.330078  5854.069824  5921.540039
# ...

# %%
sp500_historical = yf.download("^GSPC", start="2019-01-01", end="2024-12-31", interval="1d")
# Out:
# /tmp/ipykernel_73018/2291708324.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   sp500_historical = yf.download("^GSPC", start="2019-01-01", end="2024-12-31", interval="1d")
# [*********************100%***********************]  1 of 1 completed

# %%
sp500_historical.head()
# Out:
# Price             Close         High          Low         Open      Volume
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC       ^GSPC
# Date
# 2019-01-02  2510.030029  2519.489990  2467.469971  2476.959961  3733160000
# 2019-01-03  2447.889893  2493.139893  2443.959961  2491.919922  3858830000
# 2019-01-04  2531.939941  2538.070068  2474.330078  2474.330078  4234140000
# 2019-01-07  2549.689941  2566.159912  2524.560059  2535.610107  4133120000
# 2019-01-08  2574.409912  2579.820068  2547.560059  2568.110107  4120060000
