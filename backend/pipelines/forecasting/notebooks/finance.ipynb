# %%
import yfinance as yf
import feedparser

# %% [markdown]
# Stock Analysis web page to get name ticker (symbols) of different stocks
#
# https://stockanalysis.com/stocks/screener/

# %% [markdown]
# Ejemplos:
#
# MSFT &rarr; Microsoft Corporation\
# NVDA &rarr; NVIDIA Corporation\
# AAPL &rarr; Apple Inc.\
# AMZN &rarr; Amazon.com, Inc.\
# GOOG &rarr; Alphabet Inc.\
# GOOGL &rarr; Alphabet Inc.\
# META &rarr; Meta Platforms, Inc.\
# TSLA &rarr; Tesla, Inc.\
# NFLX &rarr; Netflix, Inc.\
# ORCL &rarr; Oracle Corporation\
# ^GSPC  &rarr; S&P500\

# %%
dat = yf.Ticker("NVDA")
dat.info
# Out:
# {'address1': '2788 San Tomas Expressway',
#  'city': 'Santa Clara',
#  'state': 'CA',
#  'zip': '95051',
#  'country': 'United States',
#  'phone': '408 486 2000',
#  'website': 'https://www.nvidia.com',
#  'industry': 'Semiconductors',
#  'industryKey': 'semiconductors',
#  'industryDisp': 'Semiconductors',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
dat.get_news()
# Out:
# [{'id': '989c444c-2fd9-3bd9-97d0-e5fd045877a1',
#   'content': {'id': '989c444c-2fd9-3bd9-97d0-e5fd045877a1',
#    'contentType': 'VIDEO',
#    'title': "'Mag 7' turned 'Mid 7': Is 2025 the end of tech dominance?",
# ...

# %%
import datetime as dt
today = dt.date.today().strftime('%Y-%m-%d')
stock_df = dat.history(start='2018-01-01', end=today).drop(columns=['Dividends', 'Stock Splits'])
# yf.download(["MSFT"])

# %%
stock_df.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  1871.000000  1871.000000  1871.000000  1871.000000  1.871000e+03
# mean     34.488059    35.130164    33.779534    34.485257  4.514150e+08
# std      41.365283    42.105772    40.476064    41.318592  2.113008e+08
# min       3.136509     3.223049     3.086172     3.151139  9.788400e+07
# 25%       6.234479     6.310415     6.158364     6.239678  3.012260e+08
# 50%      15.730070    16.040750    15.459333    15.809998  4.145960e+08
# 75%      42.622730    43.552228    42.078763    42.811897  5.523160e+08
# max     153.015919   153.115916   147.806407   149.416245  2.511528e+09
